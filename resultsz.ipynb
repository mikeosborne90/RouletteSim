# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import HTML


display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
jamesBond1 = pd.read_csv('results/007/100spins/results1z.csv')
jamesBond2 = pd.read_csv('results/007/100spins/results2z.csv')
jamesBond3 = pd.read_csv('results/007/100spins/results3z.csv')
jamesBond4 = pd.read_csv('results/007/100spins/results4z.csv')
jamesBond5 = pd.read_csv('results/007/100spins/results5z.csv')

# %%
del jamesBond1["run"]
del jamesBond2["run"]
del jamesBond3["run"]
del jamesBond4["run"]
del jamesBond5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = jamesBond1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))
jamesBond2.plot(ax=ax)
jamesBond3.plot(ax=ax)
jamesBond4.plot(ax=ax)
jamesBond5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='James Bond 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(jamesBond1.describe())
display(jamesBond2.describe())
display(jamesBond3.describe())
display(jamesBond4.describe())
display(jamesBond5.describe())
# Out:
#              total
# count   100.000000
# mean   1416.100000
# std     210.520735
# min     920.000000
# 25%    1277.500000
# 50%    1440.000000
# 75%    1560.000000
# max    1800.000000
#              total
# count   100.000000
# mean    977.900000
# std     119.479469
# min     710.000000
# 25%     887.500000
# 50%     995.000000
# 75%    1070.000000
# max    1200.000000
#              total
# count   100.000000
# mean    435.400000
# std     367.864215
# min     -30.000000
# 25%     130.000000
# 50%     275.000000
# 75%     780.000000
# max    1140.000000
#             total
# count   100.00000
# mean     61.20000
# std     404.96235
# min    -660.00000
# 25%    -240.00000
# 50%     -30.00000
# 75%     290.00000
# max    1030.00000
#             total
# count  100.000000
# mean   480.500000
# std    227.540095
# min    120.000000
# 25%    287.500000
# 50%    440.000000
# 75%    672.500000
# max    940.000000

# %%
jamesBond1 = pd.read_csv('results/007/1000spins/results1z.csv')
jamesBond2 = pd.read_csv('results/007/1000spins/results2z.csv')
jamesBond3 = pd.read_csv('results/007/1000spins/results3z.csv')
jamesBond4 = pd.read_csv('results/007/1000spins/results4z.csv')
jamesBond5 = pd.read_csv('results/007/1000spins/results5z.csv')

# %%
del jamesBond1["run"]
del jamesBond2["run"]
del jamesBond3["run"]
del jamesBond4["run"]
del jamesBond5["run"]

# %%
ax = jamesBond1.plot(y="total", figsize=(15,10))
jamesBond2.plot(ax=ax)
jamesBond3.plot(ax=ax)
jamesBond4.plot(ax=ax)
jamesBond5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='James Bond 1000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(jamesBond1.describe())
display(jamesBond2.describe())
display(jamesBond3.describe())
display(jamesBond4.describe())
display(jamesBond5.describe())
# Out:
#              total
# count  1000.000000
# mean   -883.120000
# std    1175.116064
# min   -2820.000000
# 25%   -1632.500000
# 50%   -1280.000000
# 75%     340.000000
# max    1720.000000
#             total
# count  1000.00000
# mean   -666.93000
# std    1504.14831
# min   -3410.00000
# 25%   -2270.00000
# 50%    -130.00000
# 75%     570.00000
# max    1480.00000
#             total
# count  1000.00000
# mean    331.09000
# std     889.13006
# min   -2230.00000
# 25%    -170.00000
# 50%     420.00000
# 75%     760.00000
# max    2020.00000
#              total
# count  1000.000000
# mean   3023.160000
# std     752.628769
# min     850.000000
# 25%    2540.000000
# 50%    3080.000000
# 75%    3590.000000
# max    4500.000000
#             total
# count  1000.00000
# mean   2946.38000
# std     876.46488
# min     820.00000
# 25%    2697.50000
# 50%    3050.00000
# 75%    3630.00000
# max    4470.00000

# %%
jamesBond1 = pd.read_csv('results/007/10000spins/results1z.csv')
jamesBond2 = pd.read_csv('results/007/10000spins/results2z.csv')
jamesBond3 = pd.read_csv('results/007/10000spins/results3z.csv')
jamesBond4 = pd.read_csv('results/007/10000spins/results4z.csv')
jamesBond5 = pd.read_csv('results/007/10000spins/results5z.csv')

# %%
del jamesBond1["run"]
del jamesBond2["run"]
del jamesBond3["run"]
del jamesBond4["run"]
del jamesBond5["run"]

# %%
ax = jamesBond1.plot(y="total",figsize=(15,10))
jamesBond2.plot(ax=ax)
jamesBond3.plot(ax=ax)
jamesBond4.plot(ax=ax)
jamesBond5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='James Bond 10000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(jamesBond1.describe())
display(jamesBond2.describe())
display(jamesBond3.describe())
display(jamesBond4.describe())
display(jamesBond5.describe())
# Out:
#               total
# count  10000.000000
# mean    -931.727000
# std     2192.105508
# min    -7700.000000
# 25%    -2810.000000
# 50%     -110.000000
# 75%      670.000000
# max     2950.000000
#              total
# count  10000.00000
# mean    -472.08800
# std     1825.29611
# min    -5360.00000
# 25%    -1522.50000
# 50%     -410.00000
# 75%     1010.00000
# max     3300.00000
#               total
# count  10000.000000
# mean   -1175.396000
# std     5013.419969
# min   -10030.000000
# 25%    -6125.000000
# 50%    -1135.000000
# 75%     3920.000000
# max     6520.000000
#              total
# count  10000.00000
# mean   -3253.69900
# std     2661.35711
# min   -10130.00000
# 25%    -4780.00000
# 50%    -3060.00000
# 75%    -1460.00000
# max     1960.00000
#               total
# count  10000.000000
# mean    4602.668000
# std     2748.312137
# min    -2190.000000
# 25%     3587.500000
# 50%     5480.000000
# 75%     6660.000000
# max     8800.000000

# %%
martingale1 = pd.read_csv('results/Martingale-noCap/100spins/results1z.csv')
martingale2 = pd.read_csv('results/Martingale-noCap/100spins/results2z.csv')
martingale3 = pd.read_csv('results/Martingale-noCap/100spins/results3z.csv')
martingale4 = pd.read_csv('results/Martingale-noCap/100spins/results4z.csv')
martingale5 = pd.read_csv('results/Martingale-noCap/100spins/results5z.csv')

# %%
del martingale1["run"]
del martingale2["run"]
del martingale3["run"]
del martingale4["run"]
del martingale5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = martingale1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))
martingale2.plot(ax=ax)
martingale3.plot(ax=ax)
martingale4.plot(ax=ax)
martingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Martingale with no max bet 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(martingale1.describe())
display(martingale2.describe())
display(martingale3.describe())
display(martingale4.describe())
display(martingale5.describe())
# Out:
#              total
# count   100.000000
# mean   1025.200000
# std      17.252141
# min     973.000000
# 25%    1010.750000
# 50%    1026.000000
# 75%    1038.250000
# max    1056.000000
#              total
# count   100.000000
# mean   1019.930000
# std      17.939998
# min     944.000000
# 25%    1007.000000
# 50%    1019.500000
# 75%    1033.250000
# max    1050.000000
#              total
# count   100.000000
# mean   1027.920000
# std      15.214082
# min    1000.000000
# 25%    1015.750000
# 50%    1028.500000
# 75%    1040.250000
# max    1055.000000
#              total
# count   100.000000
# mean   1021.730000
# std      13.479393
# min     994.000000
# 25%    1010.000000
# 50%    1022.500000
# 75%    1032.000000
# max    1046.000000
#              total
# count   100.000000
# mean   1006.540000
# std      62.530061
# min     491.000000
# 25%    1003.750000
# 50%    1016.500000
# 75%    1029.250000
# max    1041.000000

# %%
martingale1 = pd.read_csv('results/Martingale-noCap/1000spins/results1z.csv')
martingale2 = pd.read_csv('results/Martingale-noCap/1000spins/results2z.csv')
martingale3 = pd.read_csv('results/Martingale-noCap/1000spins/results3z.csv')
martingale4 = pd.read_csv('results/Martingale-noCap/1000spins/results4z.csv')
martingale5 = pd.read_csv('results/Martingale-noCap/1000spins/results5z.csv')

# %%
del martingale1["run"]
del martingale2["run"]
del martingale3["run"]
del martingale4["run"]
del martingale5["run"]

# %%
ax = martingale1.plot(y="total", figsize=(15,10))
martingale2.plot(ax=ax)
martingale3.plot(ax=ax)
martingale4.plot(ax=ax)
martingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Martingale with no max bet 1000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(martingale1.describe())
display(martingale2.describe())
display(martingale3.describe())
display(martingale4.describe())
display(martingale5.describe())
# Out:
#              total
# count  1000.000000
# mean   1257.788000
# std     151.241373
# min    1001.000000
# 25%    1124.750000
# 50%    1257.000000
# 75%    1386.250000
# max    1525.000000
#             total
# count  1000.00000
# mean   1248.62400
# std     166.49595
# min    -632.00000
# 25%    1117.75000
# 50%    1244.00000
# 75%    1383.25000
# max    1527.00000
#             total
# count  1000.00000
# mean   1254.81800
# std     152.58661
# min     769.00000
# 25%    1127.00000
# 50%    1253.50000
# 75%    1384.25000
# max    1522.00000
#              total
# count  1000.000000
# mean   1218.337000
# std     340.155781
# min   -6944.000000
# 25%    1115.750000
# 50%    1230.000000
# 75%    1363.250000
# max    1492.000000
#              total
# count  1000.000000
# mean   1254.113000
# std     154.810557
# min     631.000000
# 25%    1123.750000
# 50%    1259.500000
# 75%    1387.250000
# max    1523.000000

# %%
martingale1 = pd.read_csv('results/Martingale-noCap/10000spins/results1z.csv')
martingale2 = pd.read_csv('results/Martingale-noCap/10000spins/results2z.csv')
martingale3 = pd.read_csv('results/Martingale-noCap/10000spins/results3z.csv')
martingale4 = pd.read_csv('results/Martingale-noCap/10000spins/results4z.csv')
martingale5 = pd.read_csv('results/Martingale-noCap/10000spins/results5z.csv')

# %%
del martingale1["run"]
del martingale2["run"]
del martingale3["run"]
del martingale4["run"]
del martingale5["run"]

# %%
ax = martingale1.plot(y="total", figsize=(15,10))
martingale2.plot(ax=ax)
martingale3.plot(ax=ax)
martingale4.plot(ax=ax)
martingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Martingale with no max bet 10000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(martingale1.describe())
display(martingale2.describe())
display(martingale3.describe())
display(martingale4.describe())
display(martingale5.describe())
# Out:
#               total
# count  10000.000000
# mean    3522.255900
# std     1440.345225
# min      645.000000
# 25%     2291.750000
# 50%     3538.500000
# 75%     4754.250000
# max     6019.000000
#               total
# count  10000.000000
# mean    3541.027100
# std     1452.915248
# min    -3585.000000
# 25%     2297.750000
# 50%     3564.000000
# 75%     4801.250000
# max     6043.000000
#               total
# count  10000.000000
# mean    3512.848200
# std     1457.713522
# min    -5865.000000
# 25%     2259.750000
# 50%     3501.500000
# 75%     4767.250000
# max     6035.000000
#               total
# count  10000.000000
# mean    3505.644000
# std     1458.531883
# min    -5054.000000
# 25%     2258.750000
# 50%     3516.000000
# 75%     4749.000000
# max     6032.000000
#               total
# count  10000.000000
# mean    3485.806500
# std     1429.405167
# min    -4798.000000
# 25%     2254.750000
# 50%     3503.000000
# 75%     4728.000000
# max     5952.000000

# %%
reverseMartingale1 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results1z.csv')
reverseMartingale2 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results2z.csv')
reverseMartingale3 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results3z.csv')
reverseMartingale4 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results4z.csv')
reverseMartingale5 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results5z.csv')

# %%
del reverseMartingale1["run"]
del reverseMartingale2["run"]
del reverseMartingale3["run"]
del reverseMartingale4["run"]
del reverseMartingale5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = reverseMartingale1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))
reverseMartingale2.plot(ax=ax)
reverseMartingale3.plot(ax=ax)
reverseMartingale4.plot(ax=ax)
reverseMartingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Reverse Martingale with no max bet 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(reverseMartingale1.describe())
display(reverseMartingale2.describe())
display(reverseMartingale3.describe())
display(reverseMartingale4.describe())
display(reverseMartingale5.describe())
# Out:
#              total
# count   100.000000
# mean    972.170000
# std      16.245002
# min     945.000000
# 25%     957.750000
# 50%     970.500000
# 75%     987.000000
# max    1001.000000
#              total
# count   100.000000
# mean    979.270000
# std      31.541172
# min     950.000000
# 25%     963.000000
# 50%     973.500000
# 75%     990.000000
# max    1223.000000
#              total
# count   100.000000
# mean    979.950000
# std      29.457854
# min     949.000000
# 25%     964.750000
# 50%     978.500000
# 75%     989.000000
# max    1209.000000
#              total
# count   100.000000
# mean    976.130000
# std      15.456459
# min     949.000000
# 25%     963.750000
# 50%     975.500000
# 75%     989.000000
# max    1029.000000
#              total
# count   100.000000
# mean    975.150000
# std      16.626846
# min     948.000000
# 25%     960.000000
# 50%     974.000000
# 75%     990.000000
# max    1009.000000

# %%
reverseMartingale1 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results1z.csv')
reverseMartingale2 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results2z.csv')
reverseMartingale3 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results3z.csv')
reverseMartingale4 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results4z.csv')
reverseMartingale5 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results5z.csv')

# %%
del reverseMartingale1["run"]
del reverseMartingale2["run"]
del reverseMartingale3["run"]
del reverseMartingale4["run"]
del reverseMartingale5["run"]

# %%
ax = reverseMartingale1.plot(y="total", figsize=(15,10))
reverseMartingale2.plot(ax=ax)
reverseMartingale3.plot(ax=ax)
reverseMartingale4.plot(ax=ax)
reverseMartingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Reverse Martingale with no max bet 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(reverseMartingale1.describe())
display(reverseMartingale2.describe())
display(reverseMartingale3.describe())
display(reverseMartingale4.describe())
display(reverseMartingale5.describe())
# Out:
#              total
# count  1000.000000
# mean    757.543000
# std     144.588803
# min     498.000000
# 25%     635.750000
# 50%     765.000000
# 75%     876.000000
# max    1396.000000
#              total
# count  1000.000000
# mean    749.555000
# std     166.422322
# min     478.000000
# 25%     605.750000
# 50%     750.000000
# 75%     891.250000
# max    2018.000000
#              total
# count  1000.000000
# mean    755.303000
# std     149.481812
# min     501.000000
# 25%     634.000000
# 50%     753.500000
# 75%     876.250000
# max    1676.000000
#              total
# count  1000.000000
# mean    750.397000
# std     149.231208
# min     499.000000
# 25%     621.000000
# 50%     756.500000
# 75%     876.000000
# max    1501.000000
#              total
# count  1000.000000
# mean    750.692000
# std     169.610173
# min     479.000000
# 25%     616.750000
# 50%     743.500000
# 75%     876.250000
# max    2876.000000

# %%
reverseMartingale1 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results1z.csv')
reverseMartingale2 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results2z.csv')
reverseMartingale3 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results3z.csv')
reverseMartingale4 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results4z.csv')
reverseMartingale5 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results5z.csv')

# %%
del reverseMartingale1["run"]
del reverseMartingale2["run"]
del reverseMartingale3["run"]
del reverseMartingale4["run"]
del reverseMartingale5["run"]

# %%
ax = reverseMartingale1.plot(y="total", figsize=(15,10))
reverseMartingale2.plot(ax=ax)
reverseMartingale3.plot(ax=ax)
reverseMartingale4.plot(ax=ax)
reverseMartingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Reverse Martingale with no max bet 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(reverseMartingale1.describe())
display(reverseMartingale2.describe())
display(reverseMartingale3.describe())
display(reverseMartingale4.describe())
display(reverseMartingale5.describe())
# Out:
#              total
# count  10000.00000
# mean   -1449.77090
# std     1415.66326
# min    -3916.00000
# 25%    -2667.25000
# 50%    -1455.00000
# 75%     -207.00000
# max     2522.00000
#               total
# count  10000.000000
# mean   -1446.071900
# std     1419.979593
# min    -3929.000000
# 25%    -2677.000000
# 50%    -1416.000000
# 75%     -236.750000
# max     4491.000000
#               total
# count  10000.000000
# mean   -1464.634100
# std     1416.068877
# min    -3934.000000
# 25%    -2688.250000
# 50%    -1484.000000
# 75%     -249.000000
# max     3362.000000
#               total
# count  10000.000000
# mean   -1502.121600
# std     1440.999153
# min    -3996.000000
# 25%    -2754.000000
# 50%    -1507.000000
# 75%     -254.750000
# max     1582.000000
#               total
# count  10000.000000
# mean   -1460.285400
# std     1439.968915
# min    -3989.000000
# 25%    -2703.000000
# 50%    -1457.000000
# 75%     -209.000000
# max     4949.000000

# %%
fibonacci1 = pd.read_csv('results/Fibonacci/100spins/results1z.csv')
fibonacci2 = pd.read_csv('results/Fibonacci/100spins/results2z.csv')
fibonacci3 = pd.read_csv('results/Fibonacci/100spins/results3z.csv')
fibonacci4 = pd.read_csv('results/Fibonacci/100spins/results4z.csv')
fibonacci5 = pd.read_csv('results/Fibonacci/100spins/results5z.csv')

# %%
del fibonacci1["run"]
del fibonacci2["run"]
del fibonacci3["run"]
del fibonacci4["run"]
del fibonacci5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = fibonacci1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))

fibonacci2.plot(ax=ax)
fibonacci3.plot(ax=ax)
fibonacci4.plot(ax=ax)
fibonacci5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Fibonacci 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(fibonacci1.describe())
display(fibonacci2.describe())
display(fibonacci3.describe())
display(fibonacci4.describe())
display(fibonacci5.describe())
# Out:
#              total
# count   100.000000
# mean   1017.000000
# std       9.774219
# min    1000.000000
# 25%    1007.000000
# 50%    1019.000000
# 75%    1026.000000
# max    1031.000000
#              total
# count   100.000000
# mean    983.610000
# std      92.462812
# min     401.000000
# 25%    1001.000000
# 50%    1009.000000
# 75%    1021.000000
# max    1028.000000
#              total
# count   100.000000
# mean   1016.660000
# std      10.034506
# min     997.000000
# 25%    1009.750000
# 50%    1016.500000
# 75%    1024.250000
# max    1034.000000
#              total
# count   100.000000
# mean   1011.600000
# std       9.183868
# min     970.000000
# 25%    1006.750000
# 50%    1013.000000
# 75%    1018.000000
# max    1024.000000
#              total
# count   100.000000
# mean   1005.450000
# std       4.236386
# min     986.000000
# 25%    1003.000000
# 50%    1005.500000
# 75%    1008.000000
# max    1013.000000

# %%
fibonacci1 = pd.read_csv('results/Fibonacci/1000spins/results1z.csv')
fibonacci2 = pd.read_csv('results/Fibonacci/1000spins/results2z.csv')
fibonacci3 = pd.read_csv('results/Fibonacci/1000spins/results3z.csv')
fibonacci4 = pd.read_csv('results/Fibonacci/1000spins/results4z.csv')
fibonacci5 = pd.read_csv('results/Fibonacci/1000spins/results5z.csv')

# %%
del fibonacci1["run"]
del fibonacci2["run"]
del fibonacci3["run"]
del fibonacci4["run"]
del fibonacci5["run"]

# %%
ax = fibonacci1.plot(y="total", figsize=(15,10))
fibonacci2.plot(ax=ax)
fibonacci3.plot(ax=ax)
fibonacci4.plot(ax=ax)
fibonacci5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Fibonacci 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(fibonacci1.describe())
display(fibonacci2.describe())
display(fibonacci3.describe())
display(fibonacci4.describe())
display(fibonacci5.describe())
# Out:
#              total
# count  1000.000000
# mean   1109.877000
# std      71.969087
# min     922.000000
# 25%    1051.000000
# 50%    1105.000000
# 75%    1164.250000
# max    1241.000000
#              total
# count  1000.000000
# mean   1134.665000
# std      94.740945
# min     118.000000
# 25%    1066.000000
# 50%    1137.000000
# 75%    1206.000000
# max    1284.000000
#              total
# count  1000.000000
# mean   1103.791000
# std      77.017069
# min     542.000000
# 25%    1042.000000
# 50%    1106.000000
# 75%    1169.250000
# max    1248.000000
#             total
# count  1000.00000
# mean   1100.36800
# std      57.68945
# min     959.00000
# 25%    1051.00000
# 50%    1104.00000
# 75%    1150.00000
# max    1197.00000
#              total
# count  1000.000000
# mean   1115.597000
# std      66.348012
# min     871.000000
# 25%    1057.750000
# 50%    1121.000000
# 75%    1172.250000
# max    1234.000000

# %%
fibonacci1 = pd.read_csv('results/Fibonacci/10000spins/results1z.csv')
fibonacci2 = pd.read_csv('results/Fibonacci/10000spins/results2z.csv')
fibonacci3 = pd.read_csv('results/Fibonacci/10000spins/results3z.csv')
fibonacci4 = pd.read_csv('results/Fibonacci/10000spins/results4z.csv')
fibonacci5 = pd.read_csv('results/Fibonacci/10000spins/results5z.csv')

# %%
del fibonacci1["run"]
del fibonacci2["run"]
del fibonacci3["run"]
del fibonacci4["run"]
del fibonacci5["run"]

# %%
ax = fibonacci1.plot(y="total", figsize=(15,10))
fibonacci2.plot(ax=ax)
fibonacci3.plot(ax=ax)
fibonacci4.plot(ax=ax)
fibonacci5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Fibonacci 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(fibonacci1.describe())
display(fibonacci2.describe())
display(fibonacci3.describe())
display(fibonacci4.describe())
display(fibonacci5.describe())
# Out:
#               total
# count  10000.000000
# mean    2244.515100
# std      712.703716
# min      465.000000
# 25%     1612.750000
# 50%     2221.000000
# 75%     2850.000000
# max     3545.000000
#               total
# count  10000.000000
# mean    2174.686900
# std      708.768811
# min     -851.000000
# 25%     1564.000000
# 50%     2151.000000
# 75%     2809.000000
# max     3396.000000
#               total
# count  10000.000000
# mean    2260.139500
# std      723.726072
# min    -1059.000000
# 25%     1642.000000
# 50%     2294.500000
# 75%     2893.000000
# max     3491.000000
#               total
# count  10000.000000
# mean    2321.198700
# std      751.699706
# min     -543.000000
# 25%     1708.000000
# 50%     2284.000000
# 75%     2981.000000
# max     3654.000000
#               total
# count  10000.000000
# mean    2279.681800
# std      751.547894
# min      477.000000
# 25%     1620.750000
# 50%     2271.000000
# 75%     2943.000000
# max     3550.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert/100spins/results1z.csv")
DAlembert2 = pd.read_csv("results/D'Alembert/100spins/results2z.csv")
DAlembert3 = pd.read_csv("results/D'Alembert/100spins/results3z.csv")
DAlembert4 = pd.read_csv("results/D'Alembert/100spins/results4z.csv")
DAlembert5 = pd.read_csv("results/D'Alembert/100spins/results5z.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count   100.000000
# mean   1019.790000
# std      12.698759
# min     993.000000
# 25%    1008.750000
# 50%    1020.000000
# 75%    1030.000000
# max    1047.000000
#              total
# count   100.000000
# mean    991.720000
# std      25.598722
# min     913.000000
# 25%     979.750000
# 50%     993.000000
# 75%    1009.250000
# max    1042.000000
#              total
# count    22.000000
# mean   1002.545455
# std       5.997835
# min     988.000000
# 25%    1000.000000
# 50%    1002.500000
# 75%    1007.750000
# max    1011.000000
#              total
# count    62.000000
# mean    942.854839
# std      62.542011
# min     799.000000
# 25%     906.000000
# 50%     959.500000
# 75%     998.750000
# max    1010.000000
#              total
# count   100.000000
# mean   1020.910000
# std      14.274435
# min     993.000000
# 25%    1009.000000
# 50%    1018.000000
# 75%    1031.000000
# max    1053.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert/1000spins/results1z.csv")
DAlembert2 = pd.read_csv("results/D'Alembert/1000spins/results2z.csv")
DAlembert3 = pd.read_csv("results/D'Alembert/1000spins/results3z.csv")
DAlembert4 = pd.read_csv("results/D'Alembert/1000spins/results4z.csv")
DAlembert5 = pd.read_csv("results/D'Alembert/1000spins/results5z.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count  1000.000000
# mean   1175.485000
# std     107.144873
# min     929.000000
# 25%    1099.000000
# 50%    1181.500000
# 75%    1227.000000
# max    1430.000000
#              total
# count  1000.000000
# mean   1252.084000
# std     161.952028
# min     993.000000
# 25%    1097.000000
# 50%    1240.000000
# 75%    1400.000000
# max    1529.000000
#              total
# count   204.000000
# mean   1030.294118
# std      38.505348
# min     926.000000
# 25%     998.750000
# 50%    1038.500000
# 75%    1063.000000
# max    1099.000000
#              total
# count   858.000000
# mean    502.912587
# std     409.610195
# min    -434.000000
# 25%     205.500000
# 50%     519.500000
# 75%     845.000000
# max    1293.000000
#              total
# count   238.000000
# mean    935.890756
# std      85.473690
# min     700.000000
# 25%     882.250000
# 50%     947.000000
# 75%    1011.750000
# max    1091.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert/10000spins/results1z.csv")
DAlembert2 = pd.read_csv("results/D'Alembert/10000spins/results2z.csv")
DAlembert3 = pd.read_csv("results/D'Alembert/10000spins/results3z.csv")
DAlembert4 = pd.read_csv("results/D'Alembert/10000spins/results4z.csv")
DAlembert5 = pd.read_csv("results/D'Alembert/10000spins/results5z.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#               total
# count  10000.000000
# mean    2813.389800
# std     1485.892051
# min      144.000000
# 25%     1639.000000
# 50%     2531.500000
# 75%     3473.000000
# max     6046.000000
#              total
# count  4426.000000
# mean   1597.055355
# std     435.347627
# min     363.000000
# 25%    1249.250000
# 50%    1494.000000
# 75%    1926.000000
# max    2549.000000
#               total
# count  10000.000000
# mean   -5464.316500
# std     4303.861724
# min   -16302.000000
# 25%    -8395.250000
# 50%    -5260.500000
# 75%    -2439.750000
# max     1513.000000
#              total
# count  2392.000000
# mean   1362.566472
# std     343.929430
# min     543.000000
# 25%    1037.750000
# 50%    1349.000000
# 75%    1654.000000
# max    1954.000000
#              total
# count  2000.000000
# mean   1034.334000
# std     454.806567
# min    -146.000000
# 25%     800.750000
# 50%     987.000000
# 75%    1143.250000
# max    1964.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert-fullrun/100spins/results1z.csv")
DAlembert2 = pd.read_csv("results/D'Alembert-fullrun/100spins/results2z.csv")
DAlembert3 = pd.read_csv("results/D'Alembert-fullrun/100spins/results3z.csv")
DAlembert4 = pd.read_csv("results/D'Alembert-fullrun/100spins/results4z.csv")
DAlembert5 = pd.read_csv("results/D'Alembert-fullrun/100spins/results5z.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert-full run 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#             total
# count   100.00000
# mean    993.58000
# std      16.97067
# min     947.00000
# 25%     981.25000
# 50%     996.00000
# 75%    1006.25000
# max    1024.00000
#              total
# count   100.000000
# mean    997.450000
# std      13.622897
# min     965.000000
# 25%     988.000000
# 50%     997.500000
# 75%    1004.000000
# max    1035.000000
#             total
# count   100.00000
# mean    848.42000
# std     102.14173
# min     664.00000
# 25%     771.75000
# 50%     827.00000
# 75%     951.25000
# max    1001.00000
#              total
# count   100.000000
# mean   1026.850000
# std      16.223424
# min     999.000000
# 25%    1013.750000
# 50%    1027.000000
# 75%    1038.250000
# max    1056.000000
#             total
# count   100.00000
# mean   1026.55000
# std      19.30111
# min     994.00000
# 25%    1012.00000
# 50%    1023.50000
# 75%    1044.00000
# max    1058.00000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results1z.csv")
DAlembert2 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results2z.csv")
DAlembert3 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results3z.csv")
DAlembert4 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results4z.csv")
DAlembert5 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results5z.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert-full run 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count  1000.000000
# mean   1163.186000
# std     125.191942
# min     898.000000
# 25%    1068.750000
# 50%    1127.000000
# 75%    1259.000000
# max    1494.000000
#              total
# count  1000.000000
# mean   1094.628000
# std      96.676181
# min     729.000000
# 25%    1033.750000
# 50%    1094.000000
# 75%    1158.000000
# max    1341.000000
#              total
# count  1000.000000
# mean   1148.704000
# std     142.819914
# min     843.000000
# 25%    1021.000000
# 50%    1128.000000
# 75%    1285.250000
# max    1418.000000
#              total
# count  1000.000000
# mean    659.762000
# std     372.643715
# min    -281.000000
# 25%     303.750000
# 50%     788.000000
# 75%     981.250000
# max    1096.000000
#              total
# count  1000.000000
# mean   1215.375000
# std     151.255852
# min     842.000000
# 25%    1083.750000
# 50%    1265.000000
# 75%    1345.250000
# max    1472.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results1z.csv")
DAlembert2 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results2z.csv")
DAlembert3 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results3z.csv")
DAlembert4 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results4z.csv")
DAlembert5 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results5z.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert-full run 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#               total
# count  10000.000000
# mean    1595.039500
# std     1548.475307
# min    -2128.000000
# 25%      460.000000
# 50%     1412.000000
# 75%     2979.250000
# max     4606.000000
#               total
# count  10000.000000
# mean    2684.517300
# std     1068.852448
# min      -71.000000
# 25%     1915.750000
# 50%     2596.000000
# 75%     3641.250000
# max     4867.000000
#               total
# count  10000.000000
# mean    1494.202700
# std     1667.033102
# min    -4534.000000
# 25%     1015.000000
# 50%     1934.000000
# 75%     2714.250000
# max     3719.000000
#               total
# count  10000.000000
# mean    1909.542000
# std     1180.359171
# min    -2303.000000
# 25%     1288.000000
# 50%     1829.000000
# 75%     2681.250000
# max     4874.000000
#               total
# count  10000.000000
# mean    1340.274100
# std     1654.315413
# min    -5857.000000
# 25%      994.000000
# 50%     1625.000000
# 75%     2285.000000
# max     3532.000000
