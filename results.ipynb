# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import HTML


display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
jamesBond1 = pd.read_csv('results/007/100spins/results1.csv')
jamesBond2 = pd.read_csv('results/007/100spins/results2.csv')
jamesBond3 = pd.read_csv('results/007/100spins/results3.csv')
jamesBond4 = pd.read_csv('results/007/100spins/results4.csv')
jamesBond5 = pd.read_csv('results/007/100spins/results5.csv')

# %%
del jamesBond1["run"]
del jamesBond2["run"]
del jamesBond3["run"]
del jamesBond4["run"]
del jamesBond5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = jamesBond1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))
jamesBond2.plot(ax=ax)
jamesBond3.plot(ax=ax)
jamesBond4.plot(ax=ax)
jamesBond5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='James Bond 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(jamesBond1.describe())
display(jamesBond2.describe())
display(jamesBond3.describe())
display(jamesBond4.describe())
display(jamesBond5.describe())
# Out:
#             total
# count  100.000000
# mean   140.000000
# std    485.336497
# min   -750.000000
# 25%   -280.000000
# 50%     70.000000
# 75%    645.000000
# max    900.000000
#              total
# count   100.000000
# mean    578.500000
# std     250.455645
# min     140.000000
# 25%     340.000000
# 50%     570.000000
# 75%     777.500000
# max    1080.000000
#             total
# count   100.00000
# mean    198.00000
# std     444.81752
# min    -470.00000
# 25%    -215.00000
# 50%     155.00000
# 75%     665.00000
# max    1040.00000
#              total
# count   100.000000
# mean   1151.600000
# std     173.628653
# min     760.000000
# 25%    1020.000000
# 50%    1150.000000
# 75%    1280.000000
# max    1510.000000
#              total
# count   100.000000
# mean   1326.500000
# std     222.843765
# min     880.000000
# 25%    1180.000000
# 50%    1345.000000
# 75%    1485.000000
# max    1830.000000

# %%
jamesBond1 = pd.read_csv('results/007/1000spins/results1.csv')
jamesBond2 = pd.read_csv('results/007/1000spins/results2.csv')
jamesBond3 = pd.read_csv('results/007/1000spins/results3.csv')
jamesBond4 = pd.read_csv('results/007/1000spins/results4.csv')
jamesBond5 = pd.read_csv('results/007/1000spins/results5.csv')

# %%
del jamesBond1["run"]
del jamesBond2["run"]
del jamesBond3["run"]
del jamesBond4["run"]
del jamesBond5["run"]

# %%
ax = jamesBond1.plot(y="total", figsize=(15,10))
jamesBond2.plot(ax=ax)
jamesBond3.plot(ax=ax)
jamesBond4.plot(ax=ax)
jamesBond5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='James Bond 1000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(jamesBond1.describe())
display(jamesBond2.describe())
display(jamesBond3.describe())
display(jamesBond4.describe())
display(jamesBond5.describe())
# Out:
#              total
# count  1000.000000
# mean   -166.590000
# std     530.387389
# min   -2150.000000
# 25%    -400.000000
# 50%    -160.000000
# 75%     102.500000
# max    1140.000000
#              total
# count  1000.000000
# mean   2770.900000
# std    1189.010654
# min     860.000000
# 25%    1620.000000
# 50%    2850.000000
# 75%    3760.000000
# max    5120.000000
#             total
# count  1000.00000
# mean  -1648.63000
# std     899.51384
# min   -2940.00000
# 25%   -2400.00000
# 50%   -2055.00000
# 75%    -767.50000
# max     900.00000
#              total
# count  1000.000000
# mean   -926.500000
# std     953.877158
# min   -2630.000000
# 25%   -1600.000000
# 50%    -930.000000
# 75%    -330.000000
# max    1290.000000
#              total
# count  1000.000000
# mean  -1611.930000
# std    1279.068251
# min   -4020.000000
# 25%   -2810.000000
# 50%   -1415.000000
# 75%    -627.500000
# max    1040.000000

# %%
jamesBond1 = pd.read_csv('results/007/10000spins/results1.csv')
jamesBond2 = pd.read_csv('results/007/10000spins/results2.csv')
jamesBond3 = pd.read_csv('results/007/10000spins/results3.csv')
jamesBond4 = pd.read_csv('results/007/10000spins/results4.csv')
jamesBond5 = pd.read_csv('results/007/10000spins/results5.csv')

# %%
del jamesBond1["run"]
del jamesBond2["run"]
del jamesBond3["run"]
del jamesBond4["run"]
del jamesBond5["run"]

# %%
ax = jamesBond1.plot(y="total",figsize=(15,10))
jamesBond2.plot(ax=ax)
jamesBond3.plot(ax=ax)
jamesBond4.plot(ax=ax)
jamesBond5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='James Bond 10000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(jamesBond1.describe())
display(jamesBond2.describe())
display(jamesBond3.describe())
display(jamesBond4.describe())
display(jamesBond5.describe())
# Out:
#               total
# count  10000.000000
# mean  -11467.833000
# std     6549.282068
# min   -21380.000000
# 25%   -17272.500000
# 50%   -11530.000000
# 75%    -6737.500000
# max     1900.000000
#              total
# count  10000.00000
# mean  -12488.50500
# std     9361.83824
# min   -32260.00000
# 25%   -18600.00000
# 50%   -11430.00000
# 75%    -3920.00000
# max     1580.00000
#               total
# count  10000.000000
# mean  -13006.164000
# std     7239.502217
# min   -24110.000000
# 25%   -18400.000000
# 50%   -15550.000000
# 75%    -7790.000000
# max     1590.000000
#               total
# count  10000.000000
# mean  -16464.000000
# std     8428.810991
# min   -28100.000000
# 25%   -23850.000000
# 50%   -17935.000000
# 75%   -10270.000000
# max     1190.000000
#               total
# count  10000.000000
# mean  -22739.345000
# std    13813.634514
# min   -47790.000000
# 25%   -34892.500000
# 50%   -22910.000000
# 75%   -10520.000000
# max     1260.000000

# %%
martingale1 = pd.read_csv('results/Martingale-noCap/100spins/results1.csv')
martingale2 = pd.read_csv('results/Martingale-noCap/100spins/results2.csv')
martingale3 = pd.read_csv('results/Martingale-noCap/100spins/results3.csv')
martingale4 = pd.read_csv('results/Martingale-noCap/100spins/results4.csv')
martingale5 = pd.read_csv('results/Martingale-noCap/100spins/results5.csv')

# %%
del martingale1["run"]
del martingale2["run"]
del martingale3["run"]
del martingale4["run"]
del martingale5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = martingale1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))
martingale2.plot(ax=ax)
martingale3.plot(ax=ax)
martingale4.plot(ax=ax)
martingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Martingale with no max bet 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(martingale1.describe())
display(martingale2.describe())
display(martingale3.describe())
display(martingale4.describe())
display(martingale5.describe())
# Out:
#              total
# count   100.000000
# mean   1026.820000
# std      16.152293
# min     992.000000
# 25%    1014.000000
# 50%    1027.500000
# 75%    1040.250000
# max    1055.000000
#              total
# count   100.000000
# mean   1019.940000
# std      17.656555
# min     948.000000
# 25%    1009.000000
# 50%    1022.500000
# 75%    1033.250000
# max    1045.000000
#              total
# count   100.000000
# mean   1018.660000
# std      15.819832
# min     977.000000
# 25%    1005.750000
# 50%    1019.500000
# 75%    1032.000000
# max    1046.000000
#              total
# count   100.000000
# mean   1024.440000
# std      18.306217
# min     970.000000
# 25%    1011.000000
# 50%    1024.500000
# 75%    1040.000000
# max    1056.000000
#              total
# count   100.000000
# mean   1018.960000
# std      20.097701
# min     896.000000
# 25%    1008.000000
# 50%    1020.000000
# 75%    1032.250000
# max    1048.000000

# %%
martingale1 = pd.read_csv('results/Martingale-noCap/1000spins/results1.csv')
martingale2 = pd.read_csv('results/Martingale-noCap/1000spins/results2.csv')
martingale3 = pd.read_csv('results/Martingale-noCap/1000spins/results3.csv')
martingale4 = pd.read_csv('results/Martingale-noCap/1000spins/results4.csv')
martingale5 = pd.read_csv('results/Martingale-noCap/1000spins/results5.csv')

# %%
del martingale1["run"]
del martingale2["run"]
del martingale3["run"]
del martingale4["run"]
del martingale5["run"]

# %%
ax = martingale1.plot(y="total", figsize=(15,10))
martingale2.plot(ax=ax)
martingale3.plot(ax=ax)
martingale4.plot(ax=ax)
martingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Martingale with no max bet 1000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(martingale1.describe())
display(martingale2.describe())
display(martingale3.describe())
display(martingale4.describe())
display(martingale5.describe())
# Out:
#              total
# count  1000.000000
# mean   1238.407000
# std     149.158586
# min     524.000000
# 25%    1115.750000
# 50%    1237.000000
# 75%    1363.000000
# max    1495.000000
#              total
# count  1000.000000
# mean   1227.600000
# std     141.269541
# min     773.000000
# 25%    1105.000000
# 50%    1220.500000
# 75%    1348.000000
# max    1482.000000
#              total
# count  1000.000000
# mean   1217.608000
# std     154.718364
# min    -675.000000
# 25%    1096.750000
# 50%    1208.000000
# 75%    1345.000000
# max    1471.000000
#              total
# count  1000.000000
# mean   1249.588000
# std     142.252775
# min     964.000000
# 25%    1126.000000
# 50%    1253.000000
# 75%    1376.000000
# max    1484.000000
#              total
# count  1000.000000
# mean   1228.203000
# std     164.295444
# min   -1008.000000
# 25%    1112.000000
# 50%    1229.500000
# 75%    1351.250000
# max    1489.000000

# %%
martingale1 = pd.read_csv('results/Martingale-noCap/10000spins/results1.csv')
martingale2 = pd.read_csv('results/Martingale-noCap/10000spins/results2.csv')
martingale3 = pd.read_csv('results/Martingale-noCap/10000spins/results3.csv')
martingale4 = pd.read_csv('results/Martingale-noCap/10000spins/results4.csv')
martingale5 = pd.read_csv('results/Martingale-noCap/10000spins/results5.csv')

# %%
del martingale1["run"]
del martingale2["run"]
del martingale3["run"]
del martingale4["run"]
del martingale5["run"]

# %%
ax = martingale1.plot(y="total", figsize=(15,10))
martingale2.plot(ax=ax)
martingale3.plot(ax=ax)
martingale4.plot(ax=ax)
martingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Martingale with no max bet 10000 spins')


ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(martingale1.describe())
display(martingale2.describe())
display(martingale3.describe())
display(martingale4.describe())
display(martingale5.describe())
# Out:
#               total
# count  10000.000000
# mean    3345.114900
# std     1548.462204
# min   -61190.000000
# 25%     2182.000000
# 50%     3364.500000
# 75%     4533.000000
# max     5710.000000
#               total
# count  10000.000000
# mean    3370.954400
# std     1372.750325
# min     -761.000000
# 25%     2179.750000
# 50%     3352.500000
# 75%     4550.250000
# max     5786.000000
#               total
# count  10000.000000
# mean    3477.735200
# std     1435.797445
# min    -1272.000000
# 25%     2219.750000
# 50%     3500.000000
# 75%     4739.000000
# max     5927.000000
#               total
# count  10000.000000
# mean    3409.290200
# std     1404.367961
# min   -11178.000000
# 25%     2200.750000
# 50%     3413.000000
# 75%     4612.000000
# max     5848.000000
#               total
# count  10000.000000
# mean    3454.515900
# std     1442.342092
# min      132.000000
# 25%     2197.750000
# 50%     3439.000000
# 75%     4714.000000
# max     5943.000000

# %%
reverseMartingale1 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results1.csv')
reverseMartingale2 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results2.csv')
reverseMartingale3 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results3.csv')
reverseMartingale4 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results4.csv')
reverseMartingale5 = pd.read_csv('results/ReverseMartingale-noCap/100spins/results5.csv')

# %%
del reverseMartingale1["run"]
del reverseMartingale2["run"]
del reverseMartingale3["run"]
del reverseMartingale4["run"]
del reverseMartingale5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = reverseMartingale1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))
reverseMartingale2.plot(ax=ax)
reverseMartingale3.plot(ax=ax)
reverseMartingale4.plot(ax=ax)
reverseMartingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Reverse Martingale with no max bet 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(reverseMartingale1.describe())
display(reverseMartingale2.describe())
display(reverseMartingale3.describe())
display(reverseMartingale4.describe())
display(reverseMartingale5.describe())
# Out:
#              total
# count   100.000000
# mean    986.350000
# std      22.383424
# min     956.000000
# 25%     973.750000
# 50%     983.500000
# 75%     994.250000
# max    1118.000000
#              total
# count   100.000000
# mean    980.120000
# std      20.405624
# min     950.000000
# 25%     964.000000
# 50%     978.500000
# 75%     992.000000
# max    1062.000000
#              total
# count   100.000000
# mean    982.820000
# std      20.385368
# min     952.000000
# 25%     968.750000
# 50%     982.000000
# 75%     993.250000
# max    1101.000000
#              total
# count   100.000000
# mean    976.290000
# std      13.613937
# min     952.000000
# 25%     965.750000
# 50%     976.500000
# 75%     987.000000
# max    1002.000000
#              total
# count   100.000000
# mean    998.040000
# std      68.530303
# min     958.000000
# 25%     973.750000
# 50%     984.500000
# 75%     995.000000
# max    1511.000000

# %%
reverseMartingale1 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results1.csv')
reverseMartingale2 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results2.csv')
reverseMartingale3 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results3.csv')
reverseMartingale4 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results4.csv')
reverseMartingale5 = pd.read_csv('results/ReverseMartingale-noCap/1000spins/results5.csv')

# %%
del reverseMartingale1["run"]
del reverseMartingale2["run"]
del reverseMartingale3["run"]
del reverseMartingale4["run"]
del reverseMartingale5["run"]

# %%
ax = reverseMartingale1.plot(y="total", figsize=(15,10))
reverseMartingale2.plot(ax=ax)
reverseMartingale3.plot(ax=ax)
reverseMartingale4.plot(ax=ax)
reverseMartingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Reverse Martingale with no max bet 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(reverseMartingale1.describe())
display(reverseMartingale2.describe())
display(reverseMartingale3.describe())
display(reverseMartingale4.describe())
display(reverseMartingale5.describe())
# Out:
#              total
# count  1000.000000
# mean    737.770000
# std     154.395736
# min     467.000000
# 25%     601.000000
# 50%     740.000000
# 75%     876.250000
# max    1013.000000
#              total
# count  1000.000000
# mean    728.638000
# std     148.402865
# min     470.000000
# 25%     606.000000
# 50%     725.500000
# 75%     855.250000
# max    1006.000000
#              total
# count  1000.000000
# mean    739.573000
# std     155.059331
# min     471.000000
# 25%     605.750000
# 50%     738.500000
# 75%     873.250000
# max    1201.000000
#              total
# count  1000.000000
# mean    742.463000
# std     151.538327
# min     477.000000
# 25%     611.750000
# 50%     744.500000
# 75%     876.000000
# max    1024.000000
#             total
# count  1000.00000
# mean    748.02500
# std     145.96595
# min     483.00000
# 25%     623.75000
# 50%     750.00000
# 75%     874.25000
# max    1219.00000

# %%
reverseMartingale1 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results1.csv')
reverseMartingale2 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results2.csv')
reverseMartingale3 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results3.csv')
reverseMartingale4 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results4.csv')
reverseMartingale5 = pd.read_csv('results/ReverseMartingale-noCap/10000spins/results5.csv')

# %%
del reverseMartingale1["run"]
del reverseMartingale2["run"]
del reverseMartingale3["run"]
del reverseMartingale4["run"]
del reverseMartingale5["run"]

# %%
ax = reverseMartingale1.plot(y="total", figsize=(15,10))
reverseMartingale2.plot(ax=ax)
reverseMartingale3.plot(ax=ax)
reverseMartingale4.plot(ax=ax)
reverseMartingale5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Reverse Martingale with no max bet 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(reverseMartingale1.describe())
display(reverseMartingale2.describe())
display(reverseMartingale3.describe())
display(reverseMartingale4.describe())
display(reverseMartingale5.describe())
# Out:
#               total
# count  10000.000000
# mean   -1609.928900
# std     1513.317279
# min    -4229.000000
# 25%    -2923.250000
# 50%    -1601.500000
# 75%     -291.750000
# max     1095.000000
#               total
# count  10000.000000
# mean   -1573.258400
# std     1658.368881
# min    -4161.000000
# 25%    -2855.250000
# 50%    -1612.500000
# 75%     -291.750000
# max    62686.000000
#               total
# count  10000.000000
# mean   -1584.850700
# std     1471.273013
# min    -4125.000000
# 25%    -2862.250000
# 50%    -1602.000000
# 75%     -319.750000
# max     1007.000000
#               total
# count  10000.000000
# mean   -1545.951800
# std     1481.458348
# min    -4122.000000
# 25%    -2831.000000
# 50%    -1547.000000
# 75%     -267.000000
# max     4601.000000
#               total
# count  10000.000000
# mean   -1518.753600
# std     1457.752504
# min    -4056.000000
# 25%    -2778.250000
# 50%    -1513.500000
# 75%     -264.000000
# max     1857.000000

# %%
fibonacci1 = pd.read_csv('results/Fibonacci/100spins/results1.csv')
fibonacci2 = pd.read_csv('results/Fibonacci/100spins/results2.csv')
fibonacci3 = pd.read_csv('results/Fibonacci/100spins/results3.csv')
fibonacci4 = pd.read_csv('results/Fibonacci/100spins/results4.csv')
fibonacci5 = pd.read_csv('results/Fibonacci/100spins/results5.csv')

# %%
del fibonacci1["run"]
del fibonacci2["run"]
del fibonacci3["run"]
del fibonacci4["run"]
del fibonacci5["run"]

# %%
x = [(i+1)*10 for i in range(11)]
ax = fibonacci1.plot(y="total", figsize=(15,10))
plt.xticks(np.arange(min(x), max(x), 10))

fibonacci2.plot(ax=ax)
fibonacci3.plot(ax=ax)
fibonacci4.plot(ax=ax)
fibonacci5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Fibonacci 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(fibonacci1.describe())
display(fibonacci2.describe())
display(fibonacci3.describe())
display(fibonacci4.describe())
display(fibonacci5.describe())
# Out:
#              total
# count   100.000000
# mean   1005.900000
# std       7.970273
# min     971.000000
# 25%    1001.750000
# 50%    1005.000000
# 75%    1011.250000
# max    1019.000000
#              total
# count   100.000000
# mean   1008.540000
# std       6.968066
# min     981.000000
# 25%    1003.750000
# 50%    1008.500000
# 75%    1012.250000
# max    1022.000000
#              total
# count   100.000000
# mean    990.510000
# std      58.333332
# min     641.000000
# 25%     999.000000
# 50%    1008.000000
# 75%    1015.000000
# max    1020.000000
#              total
# count   100.000000
# mean   1017.440000
# std       8.252725
# min     990.000000
# 25%    1010.750000
# 50%    1018.500000
# 75%    1023.000000
# max    1031.000000
#             total
# count   100.00000
# mean    999.18000
# std      22.11466
# min     875.00000
# 25%     999.00000
# 50%    1004.50000
# 75%    1011.00000
# max    1017.00000

# %%
fibonacci1 = pd.read_csv('results/Fibonacci/1000spins/results1.csv')
fibonacci2 = pd.read_csv('results/Fibonacci/1000spins/results2.csv')
fibonacci3 = pd.read_csv('results/Fibonacci/1000spins/results3.csv')
fibonacci4 = pd.read_csv('results/Fibonacci/1000spins/results4.csv')
fibonacci5 = pd.read_csv('results/Fibonacci/1000spins/results5.csv')

# %%
del fibonacci1["run"]
del fibonacci2["run"]
del fibonacci3["run"]
del fibonacci4["run"]
del fibonacci5["run"]

# %%
ax = fibonacci1.plot(y="total", figsize=(15,10))
fibonacci2.plot(ax=ax)
fibonacci3.plot(ax=ax)
fibonacci4.plot(ax=ax)
fibonacci5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Fibonacci 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(fibonacci1.describe())
display(fibonacci2.describe())
display(fibonacci3.describe())
display(fibonacci4.describe())
display(fibonacci5.describe())
# Out:
#              total
# count  1000.000000
# mean   1127.162000
# std      72.491757
# min     983.000000
# 25%    1073.000000
# 50%    1130.500000
# 75%    1189.000000
# max    1260.000000
#              total
# count  1000.000000
# mean   1092.708000
# std      71.020072
# min     177.000000
# 25%    1042.750000
# 50%    1095.500000
# 75%    1144.250000
# max    1204.000000
#              total
# count  1000.000000
# mean   1109.527000
# std      75.789388
# min     469.000000
# 25%    1059.750000
# 50%    1107.000000
# 75%    1171.000000
# max    1225.000000
#              total
# count  1000.000000
# mean   1100.059000
# std      59.893345
# min     730.000000
# 25%    1056.000000
# 50%    1105.000000
# 75%    1144.000000
# max    1210.000000
#              total
# count  1000.000000
# mean   1130.676000
# std     151.976715
# min   -1457.000000
# 25%    1080.000000
# 50%    1134.000000
# 75%    1206.000000
# max    1287.000000

# %%
fibonacci1 = pd.read_csv('results/Fibonacci/10000spins/results1.csv')
fibonacci2 = pd.read_csv('results/Fibonacci/10000spins/results2.csv')
fibonacci3 = pd.read_csv('results/Fibonacci/10000spins/results3.csv')
fibonacci4 = pd.read_csv('results/Fibonacci/10000spins/results4.csv')
fibonacci5 = pd.read_csv('results/Fibonacci/10000spins/results5.csv')

# %%
del fibonacci1["run"]
del fibonacci2["run"]
del fibonacci3["run"]
del fibonacci4["run"]
del fibonacci5["run"]

# %%
ax = fibonacci1.plot(y="total", figsize=(15,10))
fibonacci2.plot(ax=ax)
fibonacci3.plot(ax=ax)
fibonacci4.plot(ax=ax)
fibonacci5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='Fibonacci 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(fibonacci1.describe())
display(fibonacci2.describe())
display(fibonacci3.describe())
display(fibonacci4.describe())
display(fibonacci5.describe())
# Out:
#               total
# count  10000.000000
# mean    2211.924200
# std      693.057231
# min    -4290.000000
# 25%     1632.000000
# 50%     2237.000000
# 75%     2775.250000
# max     3427.000000
#               total
# count  10000.000000
# mean    2176.795000
# std      688.657032
# min     -762.000000
# 25%     1593.000000
# 50%     2182.500000
# 75%     2771.250000
# max     3375.000000
#               total
# count  10000.000000
# mean    2049.813200
# std      701.943687
# min   -15486.000000
# 25%     1477.750000
# 50%     2028.000000
# 75%     2622.000000
# max     3244.000000
#               total
# count  10000.000000
# mean    2142.003600
# std      687.510892
# min    -3132.000000
# 25%     1544.750000
# 50%     2142.000000
# 75%     2741.250000
# max     3306.000000
#               total
# count  10000.000000
# mean    2230.694800
# std      697.101058
# min    -1227.000000
# 25%     1672.000000
# 50%     2207.500000
# 75%     2820.250000
# max     3462.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert/100spins/results1.csv")
DAlembert2 = pd.read_csv("results/D'Alembert/100spins/results2.csv")
DAlembert3 = pd.read_csv("results/D'Alembert/100spins/results3.csv")
DAlembert4 = pd.read_csv("results/D'Alembert/100spins/results4.csv")
DAlembert5 = pd.read_csv("results/D'Alembert/100spins/results5.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count    38.000000
# mean   1005.684211
# std       5.046301
# min     996.000000
# 25%    1001.000000
# 50%    1005.500000
# 75%    1009.750000
# max    1014.000000
#              total
# count   100.000000
# mean    946.160000
# std      62.091773
# min     779.000000
# 25%     909.000000
# 50%     972.000000
# 75%     992.500000
# max    1005.000000
#              total
# count    32.000000
# mean   1003.250000
# std      10.156835
# min     971.000000
# 25%    1000.750000
# 50%    1005.500000
# 75%    1010.000000
# max    1015.000000
#              total
# count    60.000000
# mean   1002.000000
# std      11.833592
# min     971.000000
# 25%     995.000000
# 50%    1002.000000
# 75%    1009.250000
# max    1030.000000
#              total
# count    20.000000
# mean   1003.950000
# std       3.859029
# min     997.000000
# 25%    1000.750000
# 50%    1004.500000
# 75%    1007.000000
# max    1009.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert/1000spins/results1.csv")
DAlembert2 = pd.read_csv("results/D'Alembert/1000spins/results2.csv")
DAlembert3 = pd.read_csv("results/D'Alembert/1000spins/results3.csv")
DAlembert4 = pd.read_csv("results/D'Alembert/1000spins/results4.csv")
DAlembert5 = pd.read_csv("results/D'Alembert/1000spins/results5.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count  1000.000000
# mean    378.378000
# std     536.254378
# min   -1026.000000
# 25%      56.000000
# 50%     388.500000
# 75%     891.250000
# max    1047.000000
#              total
# count   200.000000
# mean   1026.980000
# std      29.720974
# min     967.000000
# 25%    1000.750000
# 50%    1028.500000
# 75%    1049.000000
# max    1089.000000
#              total
# count   210.000000
# mean    966.971429
# std      62.919019
# min     822.000000
# 25%     918.250000
# 50%     996.000000
# 75%    1020.750000
# max    1046.000000
#              total
# count  1000.000000
# mean    356.343000
# std     537.290648
# min    -942.000000
# 25%      23.500000
# 50%     382.500000
# 75%     860.250000
# max    1034.000000
#              total
# count   204.000000
# mean    990.431373
# std      41.609020
# min     889.000000
# 25%     962.000000
# 50%     999.500000
# 75%    1013.750000
# max    1081.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert/10000spins/results1.csv")
DAlembert2 = pd.read_csv("results/D'Alembert/10000spins/results2.csv")
DAlembert3 = pd.read_csv("results/D'Alembert/10000spins/results3.csv")
DAlembert4 = pd.read_csv("results/D'Alembert/10000spins/results4.csv")
DAlembert5 = pd.read_csv("results/D'Alembert/10000spins/results5.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#               total
# count  10000.000000
# mean  -10650.747700
# std    14427.040642
# min   -48395.000000
# 25%   -24486.250000
# 50%    -1242.000000
# 75%      501.000000
# max     1568.000000
#               total
# count  10000.000000
# mean  -10197.202000
# std    12565.041607
# min   -46551.000000
# 25%   -18721.750000
# 50%    -5897.500000
# 75%      287.000000
# max     1928.000000
#               total
# count  10000.000000
# mean   -2672.072500
# std     2751.578433
# min   -10499.000000
# 25%    -4582.000000
# 50%    -3026.500000
# 75%      167.000000
# max     3256.000000
#               total
# count  10000.000000
# mean  -25677.682900
# std    18564.873432
# min   -58856.000000
# 25%   -41430.500000
# 50%   -28892.000000
# 75%    -6197.750000
# max     1259.000000
#               total
# count  10000.000000
# mean  -13426.106700
# std    13580.614898
# min   -51516.000000
# 25%   -20410.250000
# 50%   -10986.000000
# 75%    -1527.500000
# max     1495.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert-fullrun/100spins/results1.csv")
DAlembert2 = pd.read_csv("results/D'Alembert-fullrun/100spins/results2.csv")
DAlembert3 = pd.read_csv("results/D'Alembert-fullrun/100spins/results3.csv")
DAlembert4 = pd.read_csv("results/D'Alembert-fullrun/100spins/results4.csv")
DAlembert5 = pd.read_csv("results/D'Alembert-fullrun/100spins/results5.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert-full run 100 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count   100.000000
# mean   1019.940000
# std      12.944965
# min     994.000000
# 25%    1010.750000
# 50%    1019.500000
# 75%    1027.000000
# max    1050.000000
#              total
# count   100.000000
# mean    989.170000
# std      30.841745
# min     925.000000
# 25%     966.250000
# 50%     997.000000
# 75%    1005.250000
# max    1051.000000
#              total
# count   100.000000
# mean    995.370000
# std      21.874599
# min     939.000000
# 25%     988.750000
# 50%     999.500000
# 75%    1007.250000
# max    1030.000000
#              total
# count   100.000000
# mean    960.410000
# std      30.131394
# min     886.000000
# 25%     939.000000
# 50%     966.000000
# 75%     980.000000
# max    1005.000000
#              total
# count   100.000000
# mean   1023.000000
# std      16.418147
# min     994.000000
# 25%    1006.000000
# 50%    1026.000000
# 75%    1036.000000
# max    1051.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results1.csv")
DAlembert2 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results2.csv")
DAlembert3 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results3.csv")
DAlembert4 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results4.csv")
DAlembert5 = pd.read_csv("results/D'Alembert-fullrun/1000spins/results5.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert-full run 1000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#              total
# count  1000.000000
# mean    817.926000
# std     207.725801
# min     283.000000
# 25%     636.000000
# 50%     857.000000
# 75%    1000.000000
# max    1126.000000
#              total
# count  1000.000000
# mean   -937.899000
# std    1791.145162
# min   -4884.000000
# 25%   -2529.250000
# 50%    -431.500000
# 75%     933.250000
# max    1061.000000
#              total
# count  1000.000000
# mean    876.088000
# std     177.790804
# min     422.000000
# 25%     762.000000
# 50%     870.000000
# 75%    1013.000000
# max    1299.000000
#              total
# count  1000.000000
# mean    930.277000
# std     167.978585
# min     286.000000
# 25%     863.750000
# 50%     984.000000
# 75%    1035.000000
# max    1170.000000
#              total
# count  1000.000000
# mean   1042.856000
# std     131.603217
# min     683.000000
# 25%     935.750000
# 50%    1033.000000
# 75%    1152.250000
# max    1322.000000

# %%
DAlembert1 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results1.csv")
DAlembert2 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results2.csv")
DAlembert3 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results3.csv")
DAlembert4 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results4.csv")
DAlembert5 = pd.read_csv("results/D'Alembert-fullrun/10000spins/results5.csv")

# %%
del DAlembert1["run"]
del DAlembert2["run"]
del DAlembert3["run"]
del DAlembert4["run"]
del DAlembert5["run"]

# %%
ax = DAlembert1.plot(y="total", figsize=(15,10))
DAlembert2.plot(ax=ax)
DAlembert3.plot(ax=ax)
DAlembert4.plot(ax=ax)
DAlembert5.plot(ax=ax)

ax.set(xlabel='Amount of runs', ylabel='Money',
       title='DAlembert-full run 10000 spins')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')


L=plt.legend()

for i in range(5):
    L.get_texts()[i].set_text('Run '+ str(i+1))
    
ax.axhline(y=1000,color="black", linestyle='--')
plt.show()

# %%
display(DAlembert1.describe())
display(DAlembert2.describe())
display(DAlembert3.describe())
display(DAlembert4.describe())
display(DAlembert5.describe())
# Out:
#               total
# count  10000.000000
# mean  -17592.939800
# std    15389.370125
# min   -53863.000000
# 25%   -28593.250000
# 50%   -18629.500000
# 75%    -4016.500000
# max     1629.000000
#               total
# count  10000.000000
# mean  -11073.718700
# std    12161.018946
# min   -36656.000000
# 25%   -23080.250000
# 50%    -5254.000000
# 75%    -1896.000000
# max     1411.000000
#               total
# count  10000.000000
# mean    2694.906600
# std     1741.359996
# min     -899.000000
# 25%     1109.000000
# 50%     2596.500000
# 75%     4429.000000
# max     5527.000000
#               total
# count  10000.000000
# mean   -9763.725400
# std     9590.492943
# min   -30259.000000
# 25%   -18753.250000
# 50%    -5663.500000
# 75%      -65.750000
# max     1702.000000
#               total
# count  10000.000000
# mean  -15235.185800
# std    19263.515907
# min   -76481.000000
# 25%   -14277.250000
# 50%    -7357.500000
# 75%    -3458.500000
# max     1067.000000
